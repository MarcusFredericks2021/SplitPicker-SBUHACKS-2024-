# %%
import pandas as pd

# %%
import requests

url = "https://exercisedb.p.rapidapi.com/exercises/bodyPart/back"

querystring = {"limit":"10000"}

headers = {
    "X-RapidAPI-Key": "4725b440acmsh293461303e2c513p1f01a3jsnfe8269d37874",
    "X-RapidAPI-Host": "exercisedb.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# [{'bodyPart': 'back', 'equipment': 'cable', 'gifUrl': 'https://v2.exercisedb.io/image/TqnKq0eY2gCcro', 'id': '0007', 'name': 'alternate lateral pulldown', 'target': 'lats', 'secondaryMuscles': ['biceps', 'rhomboids'], 'instructions': ['Sit on the cable machine with your back straight and feet flat on the ground.', 'Grasp the handles with an overhand grip, slightly wider than shoulder-width apart.', 'Lean back slightly and pull the handles towards your chest, squeezing your shoulder blades together.', 'Pause for a moment at the peak of the movement, then slowly release the handles back to the starting position.', 'Repeat for the desired number of repetitions.']}, {'bodyPart': 'back', 'equipment': 'body weight', 'gifUrl': 'https://v2.exercisedb.io/image/NnL1dk3XPG3drn', 'id': '3293', 'name': 'archer pull up', 'target': 'lats', 'secondaryMuscles': ['biceps', 'forearms'], 'instructions': ['Start by hanging from a pull-up bar with an overhand grip, slightly wider than shoulder-width apart
# ...

# %%
url = "https://exercisedb.p.rapidapi.com/exercises/bodyPartList"
response = requests.get(url, headers=headers, params=querystring)
print(response.json())

bodyPartDF = pd.DataFrame.from_dict(response.json())
bodyPartDF = bodyPartDF.rename(columns = {0:'body_parts'})
bodyPartDF.head(10)
print(bodyPartDF.info())
# Out:
# ['back', 'cardio', 'chest', 'lower arms', 'lower legs', 'neck', 'shoulders', 'upper arms', 'upper legs', 'waist']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   body_parts  10 non-null     object
# dtypes: object(1)
# memory usage: 212.0+ bytes
# None

# %%
url = "https://exercisedb.p.rapidapi.com/exercises/equipmentList"
response = requests.get(url, headers=headers, params=querystring)

equipmentListDF = pd.DataFrame.from_dict(response.json())
equipmentListDF = equipmentListDF.rename(columns = {0:'equipment_list'})
equipmentListDF.head(10)
print(equipmentListDF.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   equipment_list  28 non-null     object
# dtypes: object(1)
# memory usage: 356.0+ bytes
# None

# %%
url = "https://exercisedb.p.rapidapi.com/exercises/targetList"
response = requests.get(url, headers=headers, params=querystring)

targetListDF = pd.DataFrame.from_dict(response.json())
targetListDF = targetListDF.rename(columns = {0:'target_list'})
targetListDF.head(10)
print(targetListDF.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   target_list  19 non-null     object
# dtypes: object(1)
# memory usage: 284.0+ bytes
# None

# %%
url = "https://exercisedb.p.rapidapi.com/exercises"
response = requests.get(url, headers=headers, params=querystring)

exerciseListDF = pd.DataFrame.from_dict(response.json())
exerciseListDF = exerciseListDF.rename(columns = {0:'exercise_list'})
exerciseListDF.head(10)
print(exerciseListDF.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1324 entries, 0 to 1323
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bodyPart          1324 non-null   object
#  1   equipment         1324 non-null   object
#  2   gifUrl            1324 non-null   object
#  3   id                1324 non-null   object
#  4   name              1324 non-null   object
#  5   target            1324 non-null   object
#  6   secondaryMuscles  1324 non-null   object
#  7   instructions      1324 non-null   object
# dtypes: object(8)
# memory usage: 82.9+ KB
# None

# %%
# %pip install "pymongo[srv]"
# Out:
# ...
#   Obtaining dependency information for pymongo[srv] from https://files.pythonhosted.org/packages/1f/3f/b2e3e18b75d5d42e79939da187efff5ed5aac6a1cc9c0ba21bbe610a33b2/pymongo-4.6.1-cp311-cp311-macosx_10_9_universal2.whl.metadata
# ...
#   Obtaining dependency information for dnspython<3.0.0,>=1.16.0 from https://files.pythonhosted.org/packages/b6/83/4a684a63d395007670bc95c1947c07045fe66141574e2f7e9e347df8499a/dnspython-2.5.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.4/305.4 kB 1.8 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 534.3/534.3 kB 11.3 MB/s eta 0:00:0000:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
uri = "mongodb+srv://marcusfredericks2021:WafeppXJY39n79MA@splitpickerdb.9k8wjks.mongodb.net/?retryWrites=true&w=majority"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
mydb = client["SplitpickerDB"]
print(mydb)
#mycol = mydb.create_collection("body_part_coll")
#print(mycol)
# Out:
# Database(MongoClient(host=['ac-5iby8r7-shard-00-02.9k8wjks.mongodb.net:27017', 'ac-5iby8r7-shard-00-01.9k8wjks.mongodb.net:27017', 'ac-5iby8r7-shard-00-00.9k8wjks.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-mnd1pc-shard-0', tls=True, server_api=<pymongo.server_api.ServerApi object at 0x14ed8fb50>), 'SplitpickerDB')
# Collection(Database(MongoClient(host=['ac-5iby8r7-shard-00-02.9k8wjks.mongodb.net:27017', 'ac-5iby8r7-shard-00-01.9k8wjks.mongodb.net:27017', 'ac-5iby8r7-shard-00-00.9k8wjks.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-mnd1pc-shard-0', tls=True, server_api=<pymongo.server_api.ServerApi object at 0x14ed8fb50>), 'SplitpickerDB'), 'body_part_coll')

# %%
# mycol = mydb.create_collection("equipment_coll")
# mycol = mydb.create_collection("target_coll")
# mycol = mydb.create_collection("exercise_coll")

# %%
collist = mydb.list_collection_names()
print(collist)
# Out:
# ['target_coll', 'equipment_coll', 'Splits', 'exercise_coll', 'body_part_coll', 'Users']

# %%
#mydb.exercise_coll.insert_many(exerciseListDF.to_dict('records'))
# Out:
# InsertManyResult([ObjectId('65c704ff8db5d588ced50627'), ObjectId('65c704ff8db5d588ced50628'), ObjectId('65c704ff8db5d588ced50629'), ObjectId('65c704ff8db5d588ced5062a'), ObjectId('65c704ff8db5d588ced5062b'), ObjectId('65c704ff8db5d588ced5062c'), ObjectId('65c704ff8db5d588ced5062d'), ObjectId('65c704ff8db5d588ced5062e'), ObjectId('65c704ff8db5d588ced5062f'), ObjectId('65c704ff8db5d588ced50630'), ObjectId('65c704ff8db5d588ced50631'), ObjectId('65c704ff8db5d588ced50632'), ObjectId('65c704ff8db5d588ced50633'), ObjectId('65c704ff8db5d588ced50634'), ObjectId('65c704ff8db5d588ced50635'), ObjectId('65c704ff8db5d588ced50636'), ObjectId('65c704ff8db5d588ced50637'), ObjectId('65c704ff8db5d588ced50638'), ObjectId('65c704ff8db5d588ced50639'), ObjectId('65c704ff8db5d588ced5063a'), ObjectId('65c704ff8db5d588ced5063b'), ObjectId('65c704ff8db5d588ced5063c'), ObjectId('65c704ff8db5d588ced5063d'), ObjectId('65c704ff8db5d588ced5063e'), ObjectId('65c704ff8db5d588ced5063f'), ObjectId('65c704ff8db5d588ced5
# ...

# %%
#mydb.target_coll.insert_many(targetListDF.to_dict('records'))
# Out:
# InsertManyResult([ObjectId('65c705838db5d588ced50b53'), ObjectId('65c705838db5d588ced50b54'), ObjectId('65c705838db5d588ced50b55'), ObjectId('65c705838db5d588ced50b56'), ObjectId('65c705838db5d588ced50b57'), ObjectId('65c705838db5d588ced50b58'), ObjectId('65c705838db5d588ced50b59'), ObjectId('65c705838db5d588ced50b5a'), ObjectId('65c705838db5d588ced50b5b'), ObjectId('65c705838db5d588ced50b5c'), ObjectId('65c705838db5d588ced50b5d'), ObjectId('65c705838db5d588ced50b5e'), ObjectId('65c705838db5d588ced50b5f'), ObjectId('65c705838db5d588ced50b60'), ObjectId('65c705838db5d588ced50b61'), ObjectId('65c705838db5d588ced50b62'), ObjectId('65c705838db5d588ced50b63'), ObjectId('65c705838db5d588ced50b64'), ObjectId('65c705838db5d588ced50b65')], acknowledged=True)

# %%
#mydb.equipment_coll.insert_many(equipmentListDF.to_dict('records'))
# Out:
# InsertManyResult([ObjectId('65c706618db5d588ced50b66'), ObjectId('65c706618db5d588ced50b67'), ObjectId('65c706618db5d588ced50b68'), ObjectId('65c706618db5d588ced50b69'), ObjectId('65c706618db5d588ced50b6a'), ObjectId('65c706618db5d588ced50b6b'), ObjectId('65c706618db5d588ced50b6c'), ObjectId('65c706618db5d588ced50b6d'), ObjectId('65c706618db5d588ced50b6e'), ObjectId('65c706618db5d588ced50b6f'), ObjectId('65c706618db5d588ced50b70'), ObjectId('65c706618db5d588ced50b71'), ObjectId('65c706618db5d588ced50b72'), ObjectId('65c706618db5d588ced50b73'), ObjectId('65c706618db5d588ced50b74'), ObjectId('65c706618db5d588ced50b75'), ObjectId('65c706618db5d588ced50b76'), ObjectId('65c706618db5d588ced50b77'), ObjectId('65c706618db5d588ced50b78'), ObjectId('65c706618db5d588ced50b79'), ObjectId('65c706618db5d588ced50b7a'), ObjectId('65c706618db5d588ced50b7b'), ObjectId('65c706618db5d588ced50b7c'), ObjectId('65c706618db5d588ced50b7d'), ObjectId('65c706618db5d588ced50b7e'), ObjectId('65c706618db5d588ced5
# ...

# %%
#mydb.body_part_coll.insert_many(bodyPartDF.to_dict('records'))
# Out:
# InsertManyResult([ObjectId('65c706618db5d588ced50b82'), ObjectId('65c706618db5d588ced50b83'), ObjectId('65c706618db5d588ced50b84'), ObjectId('65c706618db5d588ced50b85'), ObjectId('65c706618db5d588ced50b86'), ObjectId('65c706618db5d588ced50b87'), ObjectId('65c706618db5d588ced50b88'), ObjectId('65c706618db5d588ced50b89'), ObjectId('65c706618db5d588ced50b8a'), ObjectId('65c706618db5d588ced50b8b')], acknowledged=True)

# %%
from bson.objectid import ObjectId

# %%
split_example = {
    "name" : "Da Greatest PPL",
    "description" : "Whats there to describe? Its the greatest PPL",
    "day1" : {
        "is_rest" : False,
        "description" : "This is day 1",
        "exercises" : [ObjectId('65c704ff8db5d588ced50627'), ObjectId('65c704ff8db5d588ced50628')],
        "set" : [3,3],
        "reps" : [10, 10],
        "rest" : [30,30],
    },
    "day2" : {
        "is_rest" : False,
        "description" : "This is day 2",
        "exercises" : [ObjectId('65c704ff8db5d588ced50627'), ObjectId('65c704ff8db5d588ced50628')],
        "set" : [3,3],
        "reps" : [10, 10],
        "rest" : [30,30],
    },
    "day3" : {
        "is_rest" : False,
        "description" : "This is day 3",
        "exercises" : [ObjectId('65c704ff8db5d588ced50627'), ObjectId('65c704ff8db5d588ced50628')],
        "set" : [3,3],
        "reps" : [10, 10],
        "rest" : [30,30],
    },
    "day4" : {
        "is_rest" : True,
        "description" : "This is day 4",
        "exercises" : [],
        "set" : [],
        "reps" : [],
        "rest" : [],
    },
    "day5" : {
        "is_rest" : True,
        "description" : "This is day 5",
        "exercises" : [],
        "set" : [],
        "reps" : [],
        "rest" : [],
    },
    "day6" : {
        "is_rest" : True,
        "description" : "This is day 6",
        "exercises" : [],
        "set" : [],
        "reps" : [],
        "rest" : [],
    },
    "day7" : {
        "is_rest" : False,
        "description" : "This is day 7",
        "exercises" : [ObjectId('65c704ff8db5d588ced50627'), ObjectId('65c704ff8db5d588ced50628')],
        "set" : [3,3],
        "reps" : [10, 10],
        "rest" : [30,30],
    },
}

# %%
#mydb['Splits'].insert_one(split_example)
# Out:
# InsertOneResult(ObjectId('65c7469f8db5d588ced50b8c'), acknowledged=True)
